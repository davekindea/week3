# %%
import pandas as pd
data=pd.read_csv("./Data/MachineLearningRating_v3.txt",sep="|")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1632\3616083284.py:2: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("./Data/MachineLearningRating_v3.txt",sep="|")

# %%
data.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
data.tail()
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
#         Citizenship   LegalType Title Language       Bank      AccountType  \
# 1000093          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000094          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000095          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000096          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000097          ZW  Individual    Mr  English  ABSA Bank  Savings account
#
# ...

# %%
data.columns
# Out:
# Index(['UnderwrittenCoverID', 'PolicyID', 'TransactionMonth',
#        'IsVATRegistered', 'Citizenship', 'LegalType', 'Title', 'Language',
#        'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province',
#        'PostalCode', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'mmcode',
#        'VehicleType', 'RegistrationYear', 'make', 'Model', 'Cylinders',
#        'cubiccapacity', 'kilowatts', 'bodytype', 'NumberOfDoors',
#        'VehicleIntroDate', 'CustomValueEstimate', 'AlarmImmobiliser',
#        'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff',
#        'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet',
#        'SumInsured', 'TermFrequency', 'CalculatedPremiumPerTerm',
#        'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section',
#        'Product', 'StatutoryClass', 'StatutoryRiskType', 'TotalPremium',
#        'TotalClaims'],
#       dtype='object')

# %%
data.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
data.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
num_col= data.select_dtypes(include=['number'])
var=num_col.var()
# Calculate Coefficient of Variation
cv = num_col.std() / num_col.mean()
variation_table=pd.DataFrame({
    "Variance": var,
    "Coefficient of Variation":cv
})
variation_table
# Out:
#                               Variance  Coefficient of Variation
# UnderwrittenCoverID       4.006094e+09                  0.603847
# PolicyID                  2.798451e+07                  0.664855
# PostalCode                7.021728e+06                  0.877261
# mmcode                    1.850635e+14                  0.247893
# RegistrationYear          1.063667e+01                  0.001622
# Cylinders                 8.644783e-02                  0.072658
# cubiccapacity             1.960724e+05                  0.179508
# kilowatts                 3.760984e+02                  0.199503
# NumberOfDoors             2.193184e-01                  0.116518
# CustomValueEstimate       3.186780e+11                  2.503050
# NumberOfVehiclesInFleet            NaN                       NaN
# SumInsured                2.275065e+12                  2.496524
# CalculatedPremiumPerTerm  1.597615e+05                  3.390875
# ...

# %%
data["TransactionMonth"]=pd.to_datetime(data["TransactionMonth"])
data.dtypes
# Out:
# UnderwrittenCoverID                  int64
# PolicyID                             int64
# TransactionMonth            datetime64[ns]
# IsVATRegistered                       bool
# Citizenship                         object
# LegalType                           object
# Title                               object
# Language                            object
# Bank                                object
# AccountType                         object
# MaritalStatus                       object
# Gender                              object
# Country                             object
# Province                            object
# PostalCode                           int64
# MainCrestaZone                      object
# SubCrestaZone                       object
# ItemType                            object
# mmcode                             float64
# VehicleType                         object
# RegistrationYear                     int64
# make                                object
# ...

# %%
data.isnull().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
num_col = num_col.drop('NumberOfVehiclesInFleet', axis=1)

# %%
data_mode=data.mode()

data_mode
# Out:
#     UnderwrittenCoverID  PolicyID TransactionMonth IsVATRegistered  \
# 0                 85638    3870.0       2015-08-01           False
# 1                 85639       NaN              NaT             NaN
# 2                 85640       NaN              NaT             NaN
# 3                 85641       NaN              NaT             NaN
# 4                 85642       NaN              NaT             NaN
# 5                 85643       NaN              NaT             NaN
# 6                 85644       NaN              NaT             NaN
# 7                 85645       NaN              NaT             NaN
# 8                 85646       NaN              NaT             NaN
# 9                 85650       NaN              NaT             NaN
# 10                85651       NaN              NaT             NaN
#
#    Citizenship   LegalType Title Language                 Bank  \
# 0               Individual    Mr  English  First National Bank
# ...

# %%
import matplotlib.pyplot as plt
for col in num_col:
    plt.figure(figsize=(8, 6))  
    plt.hist(data[col], bins=30, color='blue', edgecolor='black') 
    plt.title(f"Histogram of {col}") 
    plt.xlabel(col)  
    plt.ylabel("Frequency") 
    plt.grid(True)  
    plt.show()

# %%
cat_col = data.select_dtypes(include=['object'])
cat_col = cat_col.drop('CapitalOutstanding', axis=1)

# %%
for col in cat_col:
    plt.figure(figsize=(8, 6))
    # Count occurrences of each category
    counts = data[col].value_counts()
    
    # Ensure the index is a list and values are a numpy array
    categories = counts.index.tolist()
    values = counts.values
    
    plt.barh(categories, values, color='purple', edgecolor='black')
    plt.title(f'Bar Chart for {col}')  
    plt.xlabel('Count') 
    plt.ylabel(col)  
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.show()

# %%
cat_col.columns
# Out:
# Index(['Citizenship', 'LegalType', 'Title', 'Language', 'Bank', 'AccountType',
#        'MaritalStatus', 'Gender', 'Country', 'Province', 'MainCrestaZone',
#        'SubCrestaZone', 'ItemType', 'VehicleType', 'make', 'Model', 'bodytype',
#        'VehicleIntroDate', 'AlarmImmobiliser', 'TrackingDevice',
#        'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt',
#        'Converted', 'CrossBorder', 'TermFrequency', 'ExcessSelected',
#        'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product',
#        'StatutoryClass', 'StatutoryRiskType'],
#       dtype='object')
